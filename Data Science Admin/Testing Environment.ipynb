# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('twitter.csv', engine='python')

# %%
print(df.head())
# Out:
#    sentiment                                              tweet
# 0          5  Two places I'd invest all my money if I could:...
# 1          5  Awesome! Google driverless cars will help the ...
# 2          5  Autonomous vehicles could reduce traffic fatal...
# 3          5  Really good presentation from Jan Becker on Bo...
# 4          5  Ford just revealed it's Automated Ford Fusion ...

# %%
df.shape
# Out:
# (2664, 2)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['neg_senti']= np.where(df['sentiment']<3, 1, 0)

# %%
df.head()
# Out:
#    sentiment                                              tweet  neg_senti
# 0          5  Two places I'd invest all my money if I could:...          0
# 1          5  Awesome! Google driverless cars will help the ...          0
# 2          5  Autonomous vehicles could reduce traffic fatal...          0
# 3          5  Really good presentation from Jan Becker on Bo...          0
# 4          5  Ford just revealed it's Automated Ford Fusion ...          0

# %%
df[df.neg_senti==1].count()
# Out:
# sentiment    775
# tweet        775
# neg_senti    775
# dtype: int64

# %%
df1=df.tweet
df1.head()
# Out:
# 0    Two places I'd invest all my money if I could:...
# 1    Awesome! Google driverless cars will help the ...
# 2    Autonomous vehicles could reduce traffic fatal...
# 3    Really good presentation from Jan Becker on Bo...
# 4    Ford just revealed it's Automated Ford Fusion ...
# Name: tweet, dtype: object

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity < 0:
        return 1
    else:
        return 0

# %%
# We create a column with the result of the analysis:
df['SA'] = np.array([ analize_sentiment(tweet) for tweet in df['tweet'] ])

# We display the updated dataframe with the new column:
display(df.head(10))
# Out:
#    sentiment                                              tweet  neg_senti  SA
# 0          5  Two places I'd invest all my money if I could:...          0   0
# 1          5  Awesome! Google driverless cars will help the ...          0   0
# 2          5  Autonomous vehicles could reduce traffic fatal...          0   0
# 3          5  Really good presentation from Jan Becker on Bo...          0   0
# 4          5  Ford just revealed it's Automated Ford Fusion ...          0   0
# 5          5  So yeah, just throwing this out there again. W...          0   0
# 6          5  @TeslaMotors Musk reluctant to partner with Ap...          0   0
# 7          5  Finished SF&gt;LA drive. Now in rush hour for ...          0   0
# 8          5  The #Google autonomous car paid a visit to Nvi...          0   0
# 9          5  Finally, a very realistic timeline for full au...          0   0

# %%
df['pre_clean_len'] = [len(t) for t in df.tweet]
df.head()
# Out:
#    sentiment                                              tweet  neg_senti  \
# 0          5  Two places I'd invest all my money if I could:...          0
# 1          5  Awesome! Google driverless cars will help the ...          0
# 2          5  Autonomous vehicles could reduce traffic fatal...          0
# 3          5  Really good presentation from Jan Becker on Bo...          0
# 4          5  Ford just revealed it's Automated Ford Fusion ...          0
#
#    SA  pre_clean_len
# 0   0             83
# 1   0             95
# 2   0             68
# 3   0            102
# 4   0            124

# %%
df.sort_values(by='pre_clean_len', ascending=False).head()
# Out:
#       sentiment                                              tweet  neg_senti  \
# 543           4  "The idea is to challenge traditional automoti...          0
# 1704          4  @Lisalynn2000 @cnnmoney Ha. It's coming. Self-...          0
# 2160          2  G-creepy self-driving car has Google street ma...          1
# 752           4  @CBCNews this am 2 car accidents &amp; 1 near ...          0
# 654           4  @cityslikr: Yes "still cars", BUT combine a Dr...          0
#
#       SA  pre_clean_len
# 543    0            145
# 1704   0            144
# 2160   1            144
# 752    0            144
# 654    1            144

# %%
df.groupby('pre_clean_len').size().sort_values(ascending=False).head()
# Out:
# pre_clean_len
# 140    104
# 139     85
# 138     73
# 136     63
# 133     56
# dtype: int64

# %%
from nltk.tokenize import WordPunctTokenizer
from bs4 import BeautifulSoup
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))
#tweet cleaner 2
def tweet_cleaner(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    refined_words=[]
    for word in words:
        if len(word)>2:
            refined_words.append(word)
    return (" ".join(refined_words)).strip()
testing = df.tweet[:100]
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result
# Out:
# ['two places invest all money could printing and self driving cars',
#  'awesome google driverless cars will help the blind travel more often',
#  'autonomous vehicles could reduce traffic fatalities',
#  'really good presentation from jan becker bosch automated vehicle research autoauto check out',
#  'ford just revealed automated ford fusion hybrid vehicle pretty amazing fordtrends ford test',
#  'yeah just throwing this out there again would totally down beta test autonomous car',
#  'musk reluctant partner with apple google but android controlled autonomous smart car would awesome',
#  'finished drive now rush hour for meeting cant wait for autonomous google car',
#  'the google autonomous car paid visit nvidia pretty cool technology',
#  'finally very realistic timeline for full autonomous car capability hats off autoforum',
#  'cool when cars are fully autonomous cause totally gonna sleep while car drives',
#  'autonomous car driving could free the billion that wasted car insurance',
#  'awesome google builds the first purpose built autonomous vehicle selfdrivencar',
#  'glad have semi autonomous vehicle this heavy rain was worse than driving blizzard weatherwednesday',
#  'chris urmson really boosted hope for autonomous vehicle viability the near future robobusiness',
#  'drive partially autonomous vehicle radar cruise control and you will believer the tech life saver',
#  'jeff owens cto fully autonomous vehicle moon shot for our industry mbs',
#  'yes elon musk says tesla fully autonomous electric vehicle will the road years',
#  'dear please hurry with the driverless cars cuz the ones driven humans are making crazy',
#  'wish had driverless car right now',
#  'driverless cars will save time accident costs will ask why let humans drive launch',
#  'half americans want live smart city with driverless cars',
#  'hope sooner study suggests that nearly all cars are expected driverless',
#  'fasten your seatbelts google driverless car worth trillions want',
#  'dad obsessed with this google driverless car this happening artificial intelligence when you adult its gonna happen',
#  'innovation its finest google trillion driverless car will commercialized sooner than think',
#  'driverless car invented google has completed over miles and only had two accidents when humans other cars hit',
#  'can wait for this standard fasten your seatbelts google driverless car worth trillions',
#  'this honestly the coolest thing ever fasten your seatbelts google driverless car worth trillions',
#  'saw the audi new driver less parking technology really awesome',
#  'car accidents are the primary killer americans driverless cars will end that should doing all can get there',
#  'this cool swivel seats big screen espresso inside the driverless car the future',
#  'would love driverless car greatidea',
#  'love see rethink the inside cars now that they driverless much could change for the better',
#  'driverless car exists glad have lol can come soon enough kperyear auto accident deaths',
#  'when fully implemented driverless vehicles could reduce accidents saving lives the each year transportationtomorrow',
#  'yes pls google says they hope use driverless cars for shopping delivery few years',
#  'can have driverless cars already',
#  'time for the auto industry create new model yes driverless model',
#  'good now ensure politicians don stand the way google says its driverless cars are ready for city streets',
#  'can wait for driverless future soooo cooooool',
#  'great presentation the this afternoon from sebastian thrun driverless cars really fascinating stuff',
#  'driverless cars cool',
#  'thank allah can come fast enough the economist schumpeter the driverless road ahead via',
#  'want sit all day codecon driverless cars and the skype instant translator are uber cool codecon',
#  'google plans having driverless cars the road next year driverless cars cool',
#  'when can get one signmeup want thefuture socool meet google newest driverless car',
#  'marylanddrivers driverless cars can come soon enough',
#  'ready disruptions how driverless cars could reshape cities the future',
#  'driverless car invented google has completed over miles and only had two accidents when humans other cars hit good morning',
#  'sooo excited for driverless cars',
#  'pumped see some driverless cars today this going great',
#  'want driverless robocar listening here ocediscovery',
#  'drive hundreds miles week bring the driverless car cannot wait stop driving',
#  'gleason except trains are very capital intensive and have limited mobility driverless cars are the best both worlds',
#  'want google driverless car',
#  'driverless ooooh that would awesome',
#  'much awesome amazing video for google next phase driverless cars via',
#  'making driverless cars which awesome',
#  'you could call driverless car and tell the car will take you there whoo hoo',
#  'google driverless cars take one',
#  'driverless taxis nyc would probably amazing application',
#  'this whole driverless car prototype thing awesome',
#  'google new driverless car has brake pedal steering wheel via this fantastic',
#  'riding driverless car bucket list this damn exciting google',
#  'this the future and now the places will can wait for the driverless car scichat',
#  'the driverless car great idea for someone like who has eye condition that makes unable drive car',
#  'this why need driverless cars',
#  'florida can wait for driverless cars soon rarely drive and many lives will saved',
#  'they coming out with driverless cars',
#  'want driverless car bad',
#  'driverless cars could also end drunk driving forever and save lives',
#  'for driverless cars sick the accidents injuries deaths people driving recklessly all the time must stop',
#  'driverless cars will eliminate traffic crowded cities says mit',
#  'less road rage the potential benefits driverless cars are stunning',
#  'the mercedes benz driverless research car looks amazing satamadik halaa',
#  'session watching and listening head googles driverless car program absolutely fascinating',
#  'driverless cars sound awesome but the actual economic impact going blow your mind',
#  'can wait for driverless cars come out this the first time excited about motor vehicles entire life',
#  'love these times from age horse less driver less travel google build its own driver less cars',
#  'hour drive ahead driverless cars can get here fast enough',
#  'driverless cars just think the potential productivity safety gains via',
#  'poll drivers love idea driverless cars driverless selfdrivingcars autonomouscar cars',
#  'google survey just asked use driverless car only wished they had hell yes radio selection cantwait takemymoney',
#  'excited for the google glass and driverless car demo just couple minutes yglsvs',
#  'driverless car appeals instead the real estate chauffeur one can become',
#  'imagine world with virtually duis massive traffic jams and increased productivity wealth driverless cars will big for',
#  'was awesome last night seeing google driverless car stanford tonight this heaven',
#  'burkhard bilger inside google driverless car man want self driving car badly',
#  'yes daughter says she can wait have her own driverless car',
#  'driverless cars love how google takes big challenges and shares insights with students',
#  'total believe google driverless car now safer than the average driver',
#  'for one very excited about self driving cars google driverless car safer than the average driver',
#  'what fun and exciting mental exercise play thinking about the future driverless cars killerapp',
#  'would like for drive with these guys driverless cars will the safest cars ever cas',
#  'driverless shared cars will much less expensive and much safer will obey rules can wait years',
#  'driverless car need get one these',
#  'volvos new suv will super safe because semi autonomous driverless controls autopia wired',
#  'first ever tweet while cruising driverless car mindboggling sensorial experience thx google whoahorsey',
#  'amazon prime air almost incredible google driverless car']

# %%
#2nd analyzer
def analize_sentiment2(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(tweet_cleaner(tweet))
    if analysis.sentiment.polarity < 0:
        return 1
    else:
        return 0

    # We create a column with the result of the analysis:
df['SA2'] = np.array([ analize_sentiment2(tweet) for tweet in df['tweet'] ])

# We display the updated dataframe with the new column:
display(df.head(10))
# Out:
#    sentiment                                              tweet  neg_senti  \
# 0          5  Two places I'd invest all my money if I could:...          0
# 1          5  Awesome! Google driverless cars will help the ...          0
# 2          5  Autonomous vehicles could reduce traffic fatal...          0
# 3          5  Really good presentation from Jan Becker on Bo...          0
# 4          5  Ford just revealed it's Automated Ford Fusion ...          0
# 5          5  So yeah, just throwing this out there again. W...          0
# 6          5  @TeslaMotors Musk reluctant to partner with Ap...          0
# 7          5  Finished SF&gt;LA drive. Now in rush hour for ...          0
# 8          5  The #Google autonomous car paid a visit to Nvi...          0
# 9          5  Finally, a very realistic timeline for full au...          0
#
#    SA  pre_clean_len  SA2
# 0   0             83    0
# 1   0             95    0
# 2   0             68    0
# 3   0            102    0
# 4   0            124    0
# 5   0             98    0
# 6   0            125    0
# 7   0             98    0
# 8   0             76    0
# 9   0            129    0

# %%
df['tweet'].isnull().sum()
# Out:
# 0

# %%
df.groupby('neg_senti').size()
# Out:
# neg_senti
# 0    1889
# 1     775
# dtype: int64

# %%
df['cleaned_tweet']= np.array([ tweet_cleaner(tweet) for tweet in df['tweet'] ])
titles = df['cleaned_tweet'].fillna('')

from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features = 300, 
                             ngram_range=(1, 1), 
                             stop_words='english',
                             binary=True)

# Use `fit` to learn the vocabulary of the titles
vectorizer.fit(titles)

# Use `tranform` to generate the sample X word matrix - one column per feature (word or n-grams)
X = vectorizer.transform(titles)

# %%
#Dimensionality Reduction on bag of words

# %%
# model random forest
from sklearn.ensemble import RandomForestClassifier
modelrf = RandomForestClassifier(n_estimators = 20, random_state=0, n_jobs=-1, class_weight='balanced')

# model logistic regression
from sklearn.linear_model import LogisticRegression
modellr = LogisticRegression(class_weight= 'balanced') 

# Use `fit` to learn the vocabulary of the titles
vectorizer.fit(titles)

# Use `tranform` to generate the sample X word matrix - one column per feature (word or n-grams)
X = vectorizer.transform(titles).toarray()
y = df['neg_senti']

from sklearn.cross_validation import cross_val_score
model= modellr
scoresR = cross_val_score(model, X, y, cv=30, scoring='recall')
print('CV Recall {}, Average Recall {}'.format(scoresR, scoresR.mean()))
# F1 = (2 x recall x precision) / (recall + precision)
scoresf1 = cross_val_score(model, X, y, cv=30, scoring='f1')
print('CV F1 {}, Average F1 {}'.format(scoresf1, scoresf1.mean()))
scoresAUC = cross_val_score(model, X, y, cv=30, scoring='roc_auc')
print('CV AUC {}, Average AUC {}'.format(scoresAUC, scoresAUC.mean()))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# CV Recall [0.73076923 0.76923077 0.73076923 0.65384615 0.65384615 0.76923077
#  0.80769231 0.61538462 0.26923077 0.46153846 0.5        0.57692308
#  0.53846154 0.69230769 0.73076923 0.65384615 0.57692308 0.80769231
#  0.76923077 0.65384615 0.65384615 0.69230769 0.80769231 0.61538462
#  0.65384615 0.72       0.88       0.72       0.68       0.76      ], Average Recall 0.6714871794871794
# CV F1 [0.67857143 0.63492063 0.7037037  0.68       0.59649123 0.74074074
#  0.7        0.47058824 0.26415094 0.375      0.35616438 0.42253521
#  0.3943662  0.52941176 0.61290323 0.51515152 0.47619048 0.71186441
#  0.55555556 0.53125    0.52307692 0.61016949 0.6        0.52459016
#  0.55737705 0.58064516 0.61971831 0.57142857 0.53125    0.52777778], Average F1 0.5531864366323949
# CV AUC [0.85225885 0.80616606 0.87851038 0.88766789 0.83150183 0.90781441
#  0.87728938 0.6978022  0.54945055 0.53113553 0.51587302 0.54578755
#  0.55128205 0.76678877 0.7954823  0.72283272 0.65689866 0.84371184
#  0.78113553 0.72893773 0.74297924 0.72710623 0.73809524 0.72832723
#  0.73595849 0.75365079 0.83936508 0.77873016 0.65968254 0.76129032], Average AUC 0.7397837514934289

# %%
# What features of these are most important for ?
modelrf.fit(X, y)

all_feature_names = vectorizer.get_feature_names()
feature_importances = pd.DataFrame({'rfFeatures' : all_feature_names, 'Importance Score': modelrf.feature_importances_})
feature_importances.sort_values('Importance Score', ascending=False).head(10)
# Out:
#     rfFeatures  Importance Score
# 94      google          0.020936
# 41        cool          0.019669
# 276       wait          0.018610
# 28        cars          0.017243
# 27         car          0.015758
# 14     awesome          0.012303
# 217       self          0.012095
# 166       need          0.011645
# 63     driving          0.011556
# 278       want          0.011501

# %%
# What features of these are most important to predict negative sentiment for Logistic Regression?
modellr.fit(X, y)

all_feature_names = vectorizer.get_feature_names()
feature_importances = pd.DataFrame({'lrFeatures' : all_feature_names, 'Importance Score': modellr.coef_[0].tolist()})
feature_importances.sort_values('Importance Score', ascending=False).head(20)
# Out:
#      lrFeatures  Importance Score
# 128        jobs          2.351344
# 53        doesn          1.993579
# 97   government          1.851629
# 132         law          1.563260
# 55         dont          1.532249
# 220        shit          1.459055
# 182       point          1.449611
# 7          aren          1.391297
# 54          don          1.377928
# 260      trains          1.272943
# 293       wrong          1.223308
# 214       scary          1.196411
# 74          fbi          1.177063
# 265       trust          1.105646
# 50       design          1.025082
# 186     problem          0.999620
# 103        hell          0.987532
# 42      crashes          0.982348
# 198      report          0.981435
# 29        cause          0.980063

# %%
test_tweet = [df.tweet[456]]
test_tweet
# Out:
# [' Great article on #disabled transportation I will opt 4  @elonmusk 2 deliver my #autonomous car http://t.co/2hJxhTPsQ6']

# %%
test_tweet = vectorizer.transform(test_tweet)

# %%
modellr.predict(test_tweet)[0]
# Out:
# 1

# %%
#using tfidf
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features = 300, 
                             ngram_range=(1, 1), 
                             stop_words='english')


# Use `fit` to learn the vocabulary
vectorizer.fit(titles)

# Use `tranform` to generate the sample X word matrix - one column per feature (word or n-grams)
X = vectorizer.transform(titles).toarray()

scores = cross_val_score(model, X, y, cv=30,scoring='recall')
print('CV AUC {}, Average AUC {}'.format(scores, scores.mean()))
# Out:
# CV AUC [0.30769231 0.11538462 0.30769231 0.42307692 0.46153846 0.30769231
#  0.53846154 0.5        0.15384615 0.30769231 0.23076923 0.19230769
#  0.07692308 0.34615385 0.23076923 0.30769231 0.23076923 0.19230769
#  0.42307692 0.42307692 0.42307692 0.23076923 0.30769231 0.26923077
#  0.26923077 0.32       0.44       0.24       0.08       0.48      ], Average AUC 0.30456410256410255

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#test aws
import psycopg2
from psycopg2 import sql
import time
## Database details
input_db_name = "osa"
input_db_user = "janaka"
input_db_password = "1qazZXC!23"
input_db_port = 5432
input_db_host = "osa.c97j4f5sor7n.eu-west-1.rds.amazonaws.com"

def create_db_connection(db_name=input_db_name, 
                         db_user=input_db_user,
                         db_password=input_db_password, 
                         db_port=input_db_port,
                         db_host=input_db_host):
    return psycopg2.connect(host=db_host, 
                            database=db_name,
                            user=db_user, 
                            password=db_password,
                            port=db_port)

#machine learning & text 
from nltk.tokenize import WordPunctTokenizer
from bs4 import BeautifulSoup
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
conn = create_db_connection()
cur = conn.cursor()

# %%
cur.execute("""SELECT datname from pg_database""")
rows = cur.fetchall()
print(rows)
# Out:
# [('template0',), ('rdsadmin',), ('template1',), ('postgres',), ('janaka',), ('osa',)]

# %%
#create incoming tweets table
drop_table_command = "DROP TABLE incoming_tweets"
cur.execute(drop_table_command)
conn.commit()
#create_table_command = "CREATE TABLE incoming_tweets(id serial PRIMARY KEY, sentiment integer NOT NULL, tweet varchar(500))"
create_table_command = "CREATE TABLE incoming_tweets(id serial PRIMARY KEY, tweet varchar(500))"
cur.execute(create_table_command)
conn.commit()

# %%
#create existing tweets table
drop_table_command = "DROP TABLE existing_tweets"
cur.execute(drop_table_command)
conn.commit()
create_table_command = "CREATE TABLE existing_tweets(id serial PRIMARY KEY, tweet varchar(500), sentiment integer NOT NULL)"
cur.execute(create_table_command)
conn.commit()

# %%
#training data
df = pd.read_csv('twitter.csv', engine='python')
df['neg_senti']= np.where(df['sentiment']<3, 1, 0)
print(df.head(), df.shape)
# Out:
#    sentiment                                              tweet  neg_senti
# 0          5  Two places I'd invest all my money if I could:...          0
# 1          5  Awesome! Google driverless cars will help the ...          0
# 2          5  Autonomous vehicles could reduce traffic fatal...          0
# 3          5  Really good presentation from Jan Becker on Bo...          0
# 4          5  Ford just revealed it's Automated Ford Fusion ...          0 (2664, 3)

# %%
#generate dummy tweets for testing
def gettweets():
    
    top5=pd.read_csv('twitter.csv', engine='python').head()
    
    conn = create_db_connection()
    cur = conn.cursor()
    for i in range(len(top5)):
        sql_insert = '''insert into incoming_tweets (tweet)
        values ('{0}') 
        '''.format(top5.tweet[i].replace("'",""))
        cur.execute(sql_insert)
        conn.commit()
    conn.close()
    
    print('Dummy Incoming tweet table created')

gettweets()
# Out:
# Dummy Incoming tweet table created

# %%
#convert tweets from postgres to pandas dataframe
def topddf():
    
    conn = create_db_connection()
    cur = conn.cursor()
    cur.execute("""SELECT * from incoming_tweets limit 2""")
    output = cur.fetchall() 
    conn.close()
    
    d = []
    for i in range(len(output)):
        d.append((output[i][1]))

    df = pd.DataFrame(d, columns=['tweet'])
    
    return df

df_test = topddf()
len(df_test)
# Out:
# 2

# %%
#tweet cleaner 2
from nltk.tokenize import WordPunctTokenizer
from bs4 import BeautifulSoup
import re
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))   

def tweet_cleaner(text):
        
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    
    refined_words=[]
    for word in words:
        if len(word)>2:
            refined_words.append(word)
            
    return (" ".join(refined_words)).strip()

testing = df.tweet
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result
# Out:
# ['two places invest all money could printing and self driving cars',
#  'awesome google driverless cars will help the blind travel more often',
#  'autonomous vehicles could reduce traffic fatalities',
#  'really good presentation from jan becker bosch automated vehicle research autoauto check out',
#  'ford just revealed automated ford fusion hybrid vehicle pretty amazing fordtrends ford test',
#  'yeah just throwing this out there again would totally down beta test autonomous car',
#  'musk reluctant partner with apple google but android controlled autonomous smart car would awesome',
#  'finished drive now rush hour for meeting cant wait for autonomous google car',
#  'the google autonomous car paid visit nvidia pretty cool technology',
#  'finally very realistic timeline for full autonomous car capability hats off autoforum',
#  'cool when cars are fully autonomous cause totally gonna sleep while car drives',
#  'autonomous car driving could free the billion that wasted car insurance',
#  'awesome google builds the first purpose built autonomous vehicle selfdrivencar',
#  'glad have semi autonomous vehicle this heavy rain was worse than driving blizzard weatherwednesday',
#  'chris urmson really boosted hope for autonomous vehicle viability the near future robobusiness',
#  'drive partially autonomous vehicle radar cruise control and you will believer the tech life saver',
#  'jeff owens cto fully autonomous vehicle moon shot for our industry mbs',
#  'yes elon musk says tesla fully autonomous electric vehicle will the road years',
#  'dear please hurry with the driverless cars cuz the ones driven humans are making crazy',
#  'wish had driverless car right now',
#  'driverless cars will save time accident costs will ask why let humans drive launch',
#  'half americans want live smart city with driverless cars',
#  'hope sooner study suggests that nearly all cars are expected driverless',
#  'fasten your seatbelts google driverless car worth trillions want',
#  'dad obsessed with this google driverless car this happening artificial intelligence when you adult its gonna happen',
#  'innovation its finest google trillion driverless car will commercialized sooner than think',
#  'driverless car invented google has completed over miles and only had two accidents when humans other cars hit',
#  'can wait for this standard fasten your seatbelts google driverless car worth trillions',
#  'this honestly the coolest thing ever fasten your seatbelts google driverless car worth trillions',
#  'saw the audi new driver less parking technology really awesome',
#  'car accidents are the primary killer americans driverless cars will end that should doing all can get there',
#  'this cool swivel seats big screen espresso inside the driverless car the future',
#  'would love driverless car greatidea',
#  'love see rethink the inside cars now that they driverless much could change for the better',
#  'driverless car exists glad have lol can come soon enough kperyear auto accident deaths',
#  'when fully implemented driverless vehicles could reduce accidents saving lives the each year transportationtomorrow',
#  'yes pls google says they hope use driverless cars for shopping delivery few years',
#  'can have driverless cars already',
#  'time for the auto industry create new model yes driverless model',
#  'good now ensure politicians don stand the way google says its driverless cars are ready for city streets',
#  'can wait for driverless future soooo cooooool',
#  'great presentation the this afternoon from sebastian thrun driverless cars really fascinating stuff',
#  'driverless cars cool',
#  'thank allah can come fast enough the economist schumpeter the driverless road ahead via',
#  'want sit all day codecon driverless cars and the skype instant translator are uber cool codecon',
#  'google plans having driverless cars the road next year driverless cars cool',
#  'when can get one signmeup want thefuture socool meet google newest driverless car',
#  'marylanddrivers driverless cars can come soon enough',
#  'ready disruptions how driverless cars could reshape cities the future',
#  'driverless car invented google has completed over miles and only had two accidents when humans other cars hit good morning',
#  'sooo excited for driverless cars',
#  'pumped see some driverless cars today this going great',
#  'want driverless robocar listening here ocediscovery',
#  'drive hundreds miles week bring the driverless car cannot wait stop driving',
#  'gleason except trains are very capital intensive and have limited mobility driverless cars are the best both worlds',
#  'want google driverless car',
#  'driverless ooooh that would awesome',
#  'much awesome amazing video for google next phase driverless cars via',
#  'making driverless cars which awesome',
#  'you could call driverless car and tell the car will take you there whoo hoo',
#  'google driverless cars take one',
#  'driverless taxis nyc would probably amazing application',
#  'this whole driverless car prototype thing awesome',
#  'google new driverless car has brake pedal steering wheel via this fantastic',
#  'riding driverless car bucket list this damn exciting google',
#  'this the future and now the places will can wait for the driverless car scichat',
#  'the driverless car great idea for someone like who has eye condition that makes unable drive car',
#  'this why need driverless cars',
#  'florida can wait for driverless cars soon rarely drive and many lives will saved',
#  'they coming out with driverless cars',
#  'want driverless car bad',
#  'driverless cars could also end drunk driving forever and save lives',
#  'for driverless cars sick the accidents injuries deaths people driving recklessly all the time must stop',
#  'driverless cars will eliminate traffic crowded cities says mit',
#  'less road rage the potential benefits driverless cars are stunning',
#  'the mercedes benz driverless research car looks amazing satamadik halaa',
#  'session watching and listening head googles driverless car program absolutely fascinating',
#  'driverless cars sound awesome but the actual economic impact going blow your mind',
#  'can wait for driverless cars come out this the first time excited about motor vehicles entire life',
#  'love these times from age horse less driver less travel google build its own driver less cars',
#  'hour drive ahead driverless cars can get here fast enough',
#  'driverless cars just think the potential productivity safety gains via',
#  'poll drivers love idea driverless cars driverless selfdrivingcars autonomouscar cars',
#  'google survey just asked use driverless car only wished they had hell yes radio selection cantwait takemymoney',
#  'excited for the google glass and driverless car demo just couple minutes yglsvs',
#  'driverless car appeals instead the real estate chauffeur one can become',
#  'imagine world with virtually duis massive traffic jams and increased productivity wealth driverless cars will big for',
#  'was awesome last night seeing google driverless car stanford tonight this heaven',
#  'burkhard bilger inside google driverless car man want self driving car badly',
#  'yes daughter says she can wait have her own driverless car',
#  'driverless cars love how google takes big challenges and shares insights with students',
#  'total believe google driverless car now safer than the average driver',
#  'for one very excited about self driving cars google driverless car safer than the average driver',
#  'what fun and exciting mental exercise play thinking about the future driverless cars killerapp',
#  'would like for drive with these guys driverless cars will the safest cars ever cas',
#  'driverless shared cars will much less expensive and much safer will obey rules can wait years',
#  'driverless car need get one these',
#  'volvos new suv will super safe because semi autonomous driverless controls autopia wired',
#  'first ever tweet while cruising driverless car mindboggling sensorial experience thx google whoahorsey',
#  'amazon prime air almost incredible google driverless car',
#  'jealous own gets ride driverless car still ready here beta one',
#  'the age driverless cars cannot come soon enough',
#  'wow driverless vehicles even the streets',
#  'self driving cars sounds good headline california okays driverless cars',
#  'with push from google california legalizes driverless cars yeah baby seen cars like this here there',
#  'the future google driverless cars space elevators mindblown',
#  'automotive technology driver less cars will reduce accidents ease congestion',
#  'cool score california becomes second state after nevada legalize driverless cars',
#  'getting one hurry with push from google california legalizes driverless cars',
#  'say word you can have driver less car california now sweet',
#  'google stocks are already skyrocketing now the driverless are approved',
#  'these are the google driverless cars hope',
#  'loved your driverless car demo wrote quick blog about',
#  'why driverless cars will make your life perfect when they get here will welcome them',
#  'driverless cars one the biggest and most exciting technology trends the next yrs deloittepredicts not the near future',
#  'just rode the navia great ride very cool driverless technology',
#  'really look forward driverless cars',
#  'mass produced driver less cars the next ten years cannot wait',
#  'the number people feed retweeting newt gingrich talking about driverless cars astounding',
#  'driverless cars will cheaper than high speed rail and better for everyone hsr waste money',
#  'driverless cars less accidents better traffic flow adding hours each day productivity fun',
#  'just passed self driving google car mountain view feels like the future',
#  'blown away with with their automatic self parking car brilliant technology for the future amazing',
#  'toyota testing self driving car technology ann arbor michigan hell yes the future now',
#  'thank you google for this selfdriving car google lexus future flyingcarnext coolsh',
#  'the future right there new google self driving car ditches the steering wheel',
#  'cnet google self driving car turning out very smart ride mindblown future',
#  'yes yes yes yes future which people simply order self driving car when they need one',
#  'couldn agree more had first ride self driving car today amazing definitely the future',
#  'went for ride google self driving car today blew mind the future now',
#  'woahhhhh google self driving car just drove that was cool future',
#  'seen the future transportation just been ride with google self driving car epic',
#  'suexecprogram can wait upgrade model self driving car the future',
#  'new life goal the person that drives google car and takes pictures',
#  'just saw the google car way too excited about this',
#  'google reportedly designing its own self driving car via geek love this more sleep the way work',
#  'the google car saw yesterday one rex',
#  'might the only person who starts cheering their car when they see car happiness feelslikechristmas',
#  'riding around self driving car believin where see yourself years',
#  'wow just learned might driving the google car around cedar for the street view holy crap excited',
#  'just saw self driving google car awesome',
#  'saw the google self driving car while driving work the man held his hands show really was driving itself impressive',
#  'video the first user self driving car lost his vision well past legally blind amazing',
#  'just saw the google car awesome toocool',
#  'saw the google car again asked could drive the driver showed how the car can see awesome',
#  'wow google self driving car action',
#  'gahhh google self driving car socool kahuna',
#  'just saw the google car young boy about the map',
#  'google car wow',
#  'google self driving car city streets cannot wait until this technology available consumers',
#  'have you hear the self driving car heard both intelligent and game changer technology',
#  'google has self driving car california dream come true',
#  'google ready for the self driving car now',
#  'mind blowing google self driving car video visualizing the driving technology via',
#  'mandatory soon wow very cool google car avoids cyclist testing pleasing',
#  'has anyone else seen the robotic self driving car google awesome',
#  'google car checkingoffthebucketlist',
#  'was just thinking finally won have drive cars anymore google car now the braille the drive thru makes sense',
#  'google has self driving car awesome',
#  'google the next stop the road self driving car where sign awesome',
#  'super cool the next stop the road self driving car',
#  'omg just saw self driving car google wow',
#  'google self driving car project want take money',
#  'another reason love working google mashable google unveils self driving car futureiscloserthanwethink',
#  'damn cute google unveils self driving car prototype',
#  'sign google just unveiled self driving car prototype without steering wheel pedals',
#  'awesome our parking found google self driving car',
#  'first ride google self driving car amaaaazing',
#  'too cool google built real self driving car without steering wheel pedals',
#  'ready just unveiled self driving car without steering wheel pedals',
#  'can have tmrrw would you buy self driving car powered',
#  'just saw google car taking street view pictures never seen one before neat dunk middle nowhere',
#  'unbelievably excited about the google self driving car',
#  'reasons the google car cool get drunk bars and not murder bus full children driving home',
#  'think more excited about the self driving car than anything else since joined just awesome',
#  'someone who never learned how drive welcome our google car overlords',
#  'genius move google make the self driving car brand approachable and cute disarmingly brilliant',
#  'love when google does futuristic stuff like this also giving the self driving car face pretty genius',
#  'google has created self driving car more driving does for you wasssup',
#  'need the self driving car google',
#  'one the first google car lol drivingwhat',
#  'incredibly awesome can wait google unveils its self driving car this incredible',
#  'just drove the google car',
#  'just passed the google car too omg wanted see one for years',
#  'excited about the self driving car project the cloudwf seriously watch this',
#  'the google self driving car should have feeling lucky button that drives you random location this gold jerry',
#  'love seeing the google car google googleearth maps geography franklin',
#  'how awesome this google self driving car with streetview cam outside figment benefit',
#  'saw the google self driving car for the first time today feel like spotted celebrity',
#  'omg just saw the google car was cool',
#  'just saw google self driving car the wild woot was extremely well behaved wants',
#  'seeing the google car drive was the most exciting thing that happened about weeks',
#  'google self driving car out front the office did mention how excited for the machine uprising love robots dontkillme',
#  'this the coolest sight see when you get home the google car returns wish was dad lucky',
#  'self driving car test steve mahan this amazing google',
#  'angione one day will ride the solar roadways self driving car while watching google glasses and will rock',
#  'like google self driving car about now',
#  'look hands sweet ride the experimental self driving car today google mountain view pic',
#  'the back self driving google car this awesome pic',
#  'google self driving car taking blind msn taco bell and dry cleaners awesome vmworld genius machines',
#  'throngs geeks surrounding the google car damn cool technology',
#  'just saw the google car awesome',
#  'for all the shit give google this genuinely cool project self driving car',
#  'bmw stepping looks too sick rather get the google car tho drives its self that mean dui teehee',
#  'just saw google self driving car handle some pretty amazing situations downtown better than human could ready',
#  'what cooler than tesla google self driving car',
#  'spotted mountainview google self driving car love technology iwanttotry mountain view',
#  'the amazing ways the google car will change the world via',
#  'the google car tons safer than most local drivers the technology proven and ready',
#  'google self driving car love what this company does and stands for the world',
#  'just saw the google car eekkk life complete',
#  'self driving car tech and innovation its finest tech car driving innovation',
#  'just saw self driving google car how awsommee',
#  'having too much fun racing google self driving car makes commuting better google interstate south',
#  'just passed google self driving car the want one those',
#  'the google car coming the google car coming man knoweth the day hour the calls get from pastor',
#  'the google car',
#  'imagine nest your google self driving car that turns the car and warms for you the winter want',
#  'can you guys hurry with the self driving car would make morning commute much better roadnap getonitgoogle',
#  'google self driving car google cars awesomeness bayarea innovation santaclara',
#  'this day late but was totally geeking out about seeing the self driving car last night just another reason',
#  'just drove past google self driving car there was guy there but wasn driving just sat there smiling awesome',
#  'both accidents caused other cars driven humans who hit the google car way too many benefits for safety with car driving itself',
#  'google self driving car taking stroll around downtown san francisco want one pic',
#  'today watched blind man who obviously could not drive get into self driven google car and become mobile incredible',
#  'you know good day when you see google car',
#  'want that google car that drives itself',
#  'very cool completely self driving car google does again',
#  'omg omg the new little baby google car cute',
#  'the google car definitely innovation for our coming years good job guys',
#  'just saw the google car life complete',
#  'just saw self driving car cruising thru love living place that has such mindblowing technology innovation',
#  'self driving cars googlecar commute auto pilot look fwd',
#  'self driving cars seem like the best technical solution this social problem far higher bridges',
#  'yay nissan says will bring multiple self driving cars market',
#  'self driving cars powered this google investment awesome',
#  'just loved the drive self driving car from mountain view freeway',
#  'self driving ubers ftw',
#  'welcome world can wait for the self driving cars can spend more time reading',
#  'self driving cars would amazing dds would thing the past hurryupscience',
#  'excited for this come self driving cars',
#  'self driving vehicles will change the world forever',
#  'awesome post aaron can wait order self driving car chauffeur through dense streets toward destination',
#  'toyota concept vehicle self driving driving mode verycool',
#  'took taxi train train train train this morning looking forward self driving electric car one day',
#  'yea plus who wants wear those stupid gloves use computer loved the self driving cars though can wait for those',
#  'couldn more excited about self driving cars',
#  'these self driving cars are dope',
#  'love self driving car',
#  'toyota new self driving car looks awesome ces',
#  'omg self driving tesla cars',
#  'dream own affordable electric self driving car that dream really far off',
#  'like own completely redesigned self driving car with among other things the front seats reversed',
#  'germans working self driving car that accelerates now that awesome',
#  'some can drive cars ourselves self driving car would give more choice and free will',
#  'take step further imagine how the world will change with self driving cars big the internet',
#  'google has gone from simple search engine self driving cars and glass just years truly mindblowing',
#  'self driving car only adds the sticker price put down for one',
#  'really excited about self driving cars who needs silly humans anyway',
#  'terrific talk self driving cars are modern miracle waiting happen bran ferren ted',
#  'want self driving rinspeed xchange could redefine life behind the wheel',
#  'watch this super cool video self driving car',
#  'learning about what next tech right now from cnet fun think about connected homes self driving cars and more',
#  'don get how merging can hard for people self driving cars can come soon enough',
#  'huq wish that were true really really want self driving car',
#  'heard that here florida self driving cars are street legal want one',
#  'are google self driving cars going ease traffic can wait bringonthebots',
#  'waiting for self driving vehicle gimme gimme',
#  'you got one those google self driving cars sweet',
#  'when the first mass produced self driving car hits the market you can bet your ass buying one',
#  'self driving car quite amazing',
#  'right full speed ahead for self driving cars',
#  'self driving milestone google autonomous cars are mastering city streets',
#  'google self driving car hits the city streets with incredible success video',
#  'self driving cars hold great promise for saving thousands lives says government official',
#  'two things ios maps are horrendously inaccurate two self driving google cars can come soon enough',
#  'need those self driving google priuses sooner than later',
#  'spent hours the car today cannnot wait what like take ride google self driving car',
#  'self driving cars cannot get here soon enough',
#  'googles self driving cars soo cool iwantone',
#  'want self driving car bad',
#  'have admit google new self driving car pretty amazing',
#  'crazy hostility cnbc this morning against google self driving car which self evidently inevitable and desirable',
#  'google self driving cars will wonders example the people logistics business codecon goog',
#  'google new self driving car watched something this earlier holy crap',
#  'check out these amazing photos goggle brand new very cute self driving car this car awesome',
#  'announces self driving cars recode conf awesome anythingispossible',
#  'self driving cars was genius strategy google',
#  'the direct and indirect opportunities self driving cars will enormous for startups',
#  'seen the future and self driving cars lexus that how google rolls',
#  'can not wait for self driving tesla',
#  'want one google prototype electric self driving car seats two has steering wheel casey johnston',
#  'google self driving taxi the true answer pubtrans ive been dreaming for decade hope they make really real',
#  'google self driving car delovely',
#  'yup and that the problem for entertainment too often over education but self driving cars are entertaining too',
#  'the self driving car will attentive something humans lack and factor many accidents',
#  'what feels like ride self driving car truly awesome',
#  'google self driving car prototype cool want put pocket backtothefuture missmycar',
#  'must have this life would complete fung google new self driving car pretty cute',
#  'you guys can poke fun google self driving car thing but someone whos banned from driving because vision love one',
#  'gammell can not wait relegate daily commute self driving car long have have commute',
#  'this awesome proper self driving city car can wait see these the streets mountain view sign',
#  'yup exactly the self driving car stuff extremely exciting',
#  'google has self driving cars built from the ground probably the most amazing thing they have done wish grandparents had had one',
#  'self driving cars significant reduction accidents and road deaths smaller insurance industry much more diversity vehicle design',
#  'self driving cars vcu brandcenter',
#  'hope get see truly self driving cars lifetime',
#  'witnessed google self driving lexus merge the perfectly between two other cars very impressed',
#  'see these self driving cars more and more now makes want one soooo bad silicon valley',
#  'wow gesturetechnology parking assist self driving cars interesting and cool report this morning',
#  'its very nice awesome that google investing futuristic stuff like glasses and self driving cars',
#  'had first journey self driving car today amazing experience can wait for these get production',
#  'getting peek self driving vehicle the test track today furtherwithford cool',
#  'jre podcast was great pretty pumped about self driving cars and look forward telling what phone buy',
#  'free self driving cars would the best public transportation obviously',
#  'incredible technology from google self driving cars',
#  'can wait for the day that self driving cars are the norm',
#  'want one those google self driving cars life would awesome',
#  'invented the car and now the verge introducing the self driving car see our breakthroughs',
#  'self driving cars are coming back yard excited wonder can borrow for commute',
#  'can wait for self driving car get here tapon traffic',
#  'study self driving cars would eliminate majority traffic deaths congestion washington some ways',
#  'like self driving car now please',
#  'very cool mercedes benz autonomous long distance drive lots progress self driving cars',
#  'the coolest thing about self driving cars that you could signal yours pick you from the airport concert',
#  'self driving mercedes benz know what want for christmas',
#  'google self driving cars user really want one',
#  'study self driving cars would eliminate majority traffic deaths congestion washington some ways',
#  'can wait for self driving cars become mainstream the roads will much safer',
#  'self driving cars projected reduce injuries save annually via',
#  'love that self driving new car smell',
#  'ready for the self driving car',
#  'ready for self driving cars the market bored driving',
#  'such impressive technology what google self driving car sees while gathering data per second',
#  'self driving car now please',
#  'can wait for those self driving taxis pic',
#  'wow affordable self driving cars could available within the next three years futuretech',
#  'can wait till the google self driving cars come out within couple years and solve the traffic provlem',
#  'google self driving car just drove was drinking rouge shakespeare oatmeal stout too cool',
#  'can wait for self driving cars imagine sending your car pick someone while you finish getting ready for the movie',
#  'swear the only car guy who loves the idea self driving cars',
#  'from glass self driving cars and now quantum computers google taking over the world and totally okay with',
#  'want self driving car like right king now',
#  'self driving cars waze uber google maps wow',
#  'finally bumped into one the google self driving cars today magnificent sight dressed toyota prius shell',
#  'the future cars exciting finally one writer speculates about the future self driving cars',
#  'wired this ingenious self driving vehicle saves lives detecting roadside bombs need',
#  'just seen post about self driving cars omg yes need that',
#  'how long till introduces self driving model will sell house for that traffic',
#  'drivers would consider self driving cars save insurance survey says andrew thurlowautomotive news',
#  'this the coolest demonstration self driving cars ever seen mae',
#  'this awesome hyundai empty car convoy stunt drivers used showcase self driving features',
#  'self driving cars are cool incredible see and learn about the technology behind them',
#  'cannot wait until the age self driving cars years tops',
#  'you can use glass the self driving car cool',
#  'cannot wait for their self driving cars then stress safety first',
#  'indeed whoa google self driving cars complete miles without accident deemed ready for commuting',
#  'went pretty fast also parked upside down just saw presentation about google self driving car very cool vmworld',
#  'woohoo sign who needs license self driving cars coming our way exponentialtech',
#  'google self driving cars need happen like now traffic jams will thing the past years',
#  'can wait for google self driving cars',
#  'google self driving car deemed ready for commuting technology',
#  'want self driving car now waitingforthefuture',
#  'google self driving cars are the coolest things ever nlcusummit google mountain view headquarter',
#  'want need google self driving cars are programmed exceed speed limits mph',
#  'gammell looking full deployment self driving cars the time hazard and should not allowed drive',
#  'give self driving car',
#  'self driving cars finally',
#  'wow self driving car that awesome cnet ford self driving car unveils itself',
#  'want one those self driving cars can sleep way class the mornings like can have that now have the technology',
#  'vinesciences google self driving car want',
#  'need one those self driving cars',
#  'imagine all semis were self driving huge labor savings plus faster delivery times since the can drive all night',
#  'self driving cars now please takemymoney',
#  'self driving cars and drone highways the future now and awesome',
#  'self driving cars cannot come soon enough',
#  'also this traffic has made abundantly clear self driving cars can come soon enough humans are inefficient and dangerous when driving',
#  'dad said the first self driving car the first person buy doesn care how much costs',
#  'great stuff man want most that self driving cars least the highway and wireless powered everything',
#  'self driving car yes',
#  'can wait for apple self driving car',
#  'self driving cars can come soon enough',
#  'much love apple google has incredible innovation being introduced mean self driving cars and project glass are insane',
#  'tedxboulder self driving cars challenge all our assumptions about infrastructure and urban planning they have enormous potential',
#  'vote for the self driving cars',
#  'thank god don have drive anymore holy crap self driving cars are now legal california',
#  'love that google dreams big then delivers much respect also helps native and also love the idea self driving cars',
#  'want self driving car wont gotta shit just sleep while takes there',
#  'self driving cars lifetime happy about this',
#  'hey hot topic trbam yay self driving cars',
#  'queuing for ces bmw self driving electric car experience amongst the first line gonna get awesome',
#  'they invented self driving car its making debut california right now been waiting for this',
#  'they creep out saw them california now the self driving car that cool',
#  'very excited for self driving cars great question thoughtprovoking',
#  'self driving cars awesome',
#  'bmws self driving car can drift safety third engage thestig mode topgear',
#  'self driving cars five years yessss',
#  'love audi ces self driving car checkinces',
#  'self driving cars that what want',
#  'and begins first self driving car commercially available yes driveme',
#  'cannot wait until get self driving cars and reclaim all the wasted space from parked cars and wasted resources from car ownership',
#  'few weeks driving and already falling asleep the road like newborn self driving car definitely for lawmakers',
#  'self driving cars can come soon enough also willing beta test one goodbyeparkinglots google',
#  'can wait until can buy self driving car california self driving car permits take effect today',
#  'can wait until all have self driving cars',
#  'from self driving cars parties the moon the next decades are gonna rock',
#  'simply excellent took ride google self driving car the verge',
#  'very much look forward self driving cars traffic',
#  'huge fan self driving cars and this article awesome',
#  'the dreamers case you missed google self driving car prototype here followusandgrow',
#  'want self driving cars could work read watch videos chat with friends etc instead sitting traffic',
#  'once everyone has self driving cars and outlaw motorcycles the roads will better place',
#  'self driving food trucks that converge upon foursquare swarming locations genius how about uber for food trucks',
#  'yeah california approves self driving cars public streets',
#  'really need self driving cars save lives gas ghg with automated driving techla',
#  'cute want one google self driving car',
#  'after seeing how many people around here call text while driving the self driving car cannot happen fast enough',
#  'hope keep right drive self driving car will amazing and change everything this video great',
#  'uberfacts self driving cars are legal nevada florida and california want one what the fuucck where are they',
#  'well duh pumped see self driving cars the road',
#  'self driving cars would result traffic jams and reduce vehicular related deaths tenfold',
#  'entered self driving tesla through the passenger door like this whole not having drive thing',
#  'autonomous semi autonomous cars could save lives eliminating potentially fatal accidents futurelooksbright',
#  'commuting with self driving cars now that exciting futurenow newyorkerinsf',
#  'the connected car will create massive opportunities for tech and telecom companies',
#  'driver less cars can come quick enough trafficissues takepeopleoutoftheequation',
#  'driverless cars are going have enormous impact our economy increase efficiency roads reduce emissions thplan',
#  'want driverless car would make commute fun',
#  'teamed with adasworks build amazing driverless car mechanism',
#  'uber self driving cars big accessibility angle ride sharing and driverless cars big for folks like who can drive',
#  'what think new car that can drive itself legally blind guy license think its incredible',
#  'androidto the miracle aspect google self driving car that blind individual can now commute independently',
#  'hey need self driving car and need now',
#  'can wait till get self driving cars coldsandriding',
#  'with all self driving cars traffic would thing the past',
#  'self driving cars literally cannot come fast enough meter maids need find new lines work please yesterday',
#  'ready for self driving cars driving such waste productivity slotosf',
#  'can wait for self driving cars the standard',
#  'love the new google self driving cars',
#  'exciting ann arbor could get driverless vehicles',
#  'driverless cars are the future artificial intelligence many possibilities innovation',
#  'want self driving car neednow',
#  'self driving cars will makes roads safer and travel more relaxing',
#  'audi testing tampa today hoping get peek the driverless car cool',
#  'looking forward autonomous vehicle conference anaheim high tech rocks',
#  'bmw autonomous driving prototype nearing completion can more excited future',
#  'google autonomous car sooooo cute can have one',
#  'driverless car would help everyone mobility for all',
#  'showed grandma self driving car video she wants one now',
#  'very cool that ford believes driverless cars will ready that soon',
#  'cross country tour driverless car yes more time for scenery cantwait future',
#  'the future buying one these audi ready test autonomous cars public roads ces ces',
#  'audi test driving their driverless car tampa today pretty cool',
#  'autonomous car quite potential business case markets like north america speeds for every single road defined even freeways',
#  'nissan have autonomous car the year sign',
#  'huge advances autonomous cars hate parking audi unveiled self driving car that can park itself',
#  'great article disabled transportation will opt deliver autonomous car',
#  'volvo awesome new autonomous self parking car its own valet',
#  'less than five years can use the google autonomous car will get the list now',
#  'look forward seeing google self driving car and other autonomous vehicles driving around the district',
#  'took ride google self driving car lived tell about autonomous',
#  'nissan debuts first ever fly wire automobile steering system your autonomous car gonna love amd',
#  'whoa just peeped autonomous google car',
#  'very cool video how autonomous car works from where opening tomorrow chmwhereto',
#  'reuss says google autonomous car looks kind like and that kind cool',
#  'imagine world drunk driving deaths drunk riding autonomous car safer than sober driving',
#  'the icar isn autonomous but way way more fun drive than google bubble car',
#  'thx bringing their autonomous car congress this technology will literally drive the future',
#  'autonomous driving advantage your car can drive itself the shop you don have wait around some smelly waiting room',
#  'showing video google autonomous car very cool miles driven driver interaction across vehicles',
#  'google should buy tesla and uber mix little autonomous car into the mix and solve all transportation problems sentfromtraffic',
#  'fascinating presentation chris urmson head google autonomous car the hill rayburn',
#  'drivers would opt for autonomous driving for cheaper car insurance well',
#  'put lay terms autonomous nuclear powered car just landed itself mars using rocket crane this huge',
#  'there some great projects being worked our robotics lab like autonomous car and lego builder wccc love hands approach',
#  'last night saw horse cops makes have hope for the car once silly autonomous vehicles take over the market',
#  'looking forward the day when google and amazon drones fight out deliver autonomous car',
#  'autonomus car will drive miss daisy and hope autonomous vehicles now legal california autopia wired',
#  'autonomous car yes please innovation',
#  'sucks the luddites who have appreciation for fine automobiles autonomous car technology here like always dreamt',
#  'tesla ceo musk sees fully autonomous car ready five six years via',
#  'ceo isn talking about this right now but autonomous car concept uses less weight and energy ceraweek',
#  'yup wow audi cars now park themselves first automaker with autonomous vehicle license nevada',
#  'ite technical conference great google autonomous vehicle presentation',
#  'one solution poor cab service call your autonomous vehicle',
#  'cross fingers for google autonomous vehicle announcement googleio',
#  'behold the autonomous vehicle being back rocks singularityu gsp emergingtech',
#  'look forward speaking the florida autonomous vehicle summit this friday about innovation transportation sayfie',
#  'packed house trbam thanks friends and all the autonomous vehicle enthusiasts for coming out',
#  'description the navia low speed autonomous vehicle news love see someday',
#  'alert licence plate number continental autonomous vehicle that took off with boss wow',
#  'given how ornery and rude this megabus driver looking forward when gets replaced autonomous vehicle robot',
#  'fascinating what california autonomous vehicle driving permit looks like',
#  'given how ornery and rude this driver looking forward when gets replaced autonomous vehicle robot sac',
#  'someone drove the darpa car over break why was not invited',
#  'perfect darpa will sponsor self driving car',
#  'okay driverless cars safe reliable vision necessary via',
#  'other news public driverless cars could actually great for the environment',
#  'woot can wait try uber purchases driverless cars from google',
#  'can wait try this uber purchase driverless cars from google',
#  'uber purchase driverless cars from google things are getting interesting',
#  'was faked out for few minutes guess geeking out over how cool driverless cars would clouded gauge',
#  'nissan says will release driverless car and that good thing because humans are terrible driving',
#  'brilliant sci piece from uber purchase driverless cars from google',
#  'can wait for the day when driverless cars make parking tickets and searching for parking spots things the past',
#  'want driverless car auvsi secretary states investing smart transportation cdw via',
#  'also the google driverless cars have accident rate date',
#  'the hacking driverless vehicles talk good defcon',
#  'yes driverless bus interesting',
#  'driverless cars chairs moved brain function robots who can actively learn new things turn the science channel now amazing',
#  'chief legal officer david drummond driverless cars not far off will have huge safety urban planning benefits',
#  'technology for driverless cars will make driver cars better too',
#  'get ready for the mother all generation gaps driverless cars here come',
#  'need driverless cars asap check out',
#  'driverless car you get the passenger seat and drive you wow pic',
#  'ces was awesome ubuntu phone coming out soon tvsmeh oled yes saw lots innovation from smaller companies driverless lexus',
#  'google driverless car world single lane freeway could transport vehicles hour from today',
#  'want driverless car',
#  'driverless cars are going change our lives soon',
#  'can stop the future driving rel fatalities fell the lowest since incoming driverless cars cheaper insurence',
#  'mind blown fasten your seatbelts google driverless car worth trillions',
#  'whattheffacts driverless car has completed over miles only had accidents when humans other cars hit great for drunks',
#  'the glamour filing for tomorrow morning from the floor driverless cars',
#  'guess what were driving next the driverless car nice pic',
#  'the beginning good series articles fasten your seatbelts google driverless car worth trillions forbes',
#  'can wait fasten your seatbelts google driverless car worth trillions forbes',
#  'fasten your seatbelts google driverless car worth trillions',
#  'fasten your seatbelts google driverless car worth trillions drive for lot less',
#  'excited about today hair music and driverless cars going good one carolinanow',
#  'with google team google glasses driverless car and loon wifi thru high alt balloons fun',
#  'vanwa regional transportation council had interesting testimony about driverless cars fewer duis and drivers licenses needed',
#  'whoa google driverless cabs launch nyc',
#  'the future here thanks the driverless revolution rolls',
#  'great piece about excellent trip driverless cadillac thru pittsburgh',
#  'who hoo california regulate driverless cars the end cdntech',
#  'driverless cars are our future sxsw sxsw technology',
#  'dope swivel seats big screen espresso machine driverless car the future',
#  'checking out the event transportationtomorrow the future now driverless vehicles jaxevents',
#  'think that short sighted the long run transit continues grow that happens driverless solves problems',
#  'for one cannot wait for driverless cars tired people using their cars lethal weapons',
#  'man had this dream about driverless car was awesome',
#  'want driverless car someone invent one',
#  'dont make driverless cars make the act driving work not required',
#  'the idea challenge traditional automotive design the geneva auto show tesla very sexy driverless car',
#  'driverless cars could free urban land when can that happen nyc more room for cronuts right sxsw',
#  'sxsw favorites driverless cars could shape ways design cities optimization programs change day day life autonomous govlabsxsw',
#  'driverless cars should exist speeding tickets don',
#  'can wait order groceries from google glass while riding driverless car',
#  'driverless cars eyeglasses internet balloons wonderful wizards google are targeting unwired people',
#  'driverless cars combined with carsharing would drastically improve asset utilization reducing traffic',
#  'for those wondering when the driver less car may available interesting interview',
#  'driverless car invented google has completed over miles and only had two accidents when humans other cars hit horne',
#  'driverless car invented google has completed over miles and only had two accidents when humans other cars hit',
#  'dont trust anyone driving dont even trust damn self that much you shouldn are the weak link driverless',
#  'problem there there still driver want driverless transport humans are waste the transport world',
#  'think how much driving infrastructure won needed with driverless cars stop signs for example cars can adjust never stop',
#  'google driverless cars are mastering city streets from',
#  'driverless cars fly land thousands miles airplanes auto pilot why not cars',
#  'driverless cars fly land thousands airplanes auto pilot why not cars',
#  'driverless cars are mastering city streets google says google says that cars has programmed drive',
#  'the future transportation our own backyard flatt driverless google selfdriving',
#  'how cool would transparent car rather have driverless car driverlesscar',
#  'ber courier launch was bound happen again can wait till hooks them with driverless cars scifilyfe',
#  'google driverless cars are mastering city streets from the future upon tvp',
#  'google driverless cars are mastering city streets',
#  'google driverless cars are mastering city streets',
#  'google says its driverless cars are mastering city streets google says has turned corner its pursuit',
#  'driverless cars cannot come soon enough true',
#  'hope the driverless cars get here pretty soon eyesight getting pretty bad',
#  'aggressive drivers bully conservative human ones and nbd also coordinated driverless cars could box offenders',
#  'google driverless cars are mastering city streets',
#  'very cool update from performance driverless cars well worth watching minute video well',
#  'drudge report google driverless cars master city streets has upgrade from the morons hwy',
#  'driverless cars will equipped with emergency first response system healthtech',
#  'urban sprawl could decrease with driverless cars given that the required reaction time space between cars decreases',
#  'best thing would not car like flawlessly dispatched driverless car share iotchat',
#  'imagine this uber waze google driver less cars robot thats takes you home the fastest way possible wishfulthinking techdreams',
#  'google driverless cars are mastering city streets google says that cars has programmed drive themselves',
#  'google says its driverless cars starting master city streets per the wish they hurry they could drive around',
#  'google driverless cars are mastering city street google says that cars has programmed drive themselves',
#  'google driverless cars are mastering city streets from the future now',
#  'fewer injuries and deaths occur all for driverless cars',
#  'cant believe have driverless cars cool and scary the same time',
#  'trucking should concerned about how quickly google driverless car technology will legal otr game changer',
#  'good idea for the next ten years transition driverless cars',
#  'driverless taxis could interesting',
#  'google has driverless car prototype you know what that means that sucker who always has the gets have fun too',
#  'now that google has made the driverless car ill longer mad can find parking car drive around the block til return',
#  'california florida and nevada have all legalized driverless cars acceptance spreading',
#  'late the party realizing google waze purchase quite intriguing when you consider their driverless cars',
#  'google releasing driverless car this would solve all problems and save friends from being permanent chauffeurs',
#  'hjoseph have driverless cars may eliminate the need for trains busses',
#  'google driverless car good news for bad drivers goog cool car just for',
#  'first question google wife does have stereo mean driverless super cool etc but you need some sounds',
#  'the concept uber driverless cars ridiculous and awesome',
#  'far concerned google can evil they want they make the driverless car reality',
#  'and need one these driverless cars',
#  'driverless cars cool but there needs manual control option for unpredictable circumstances',
#  'driverless cars could enormous ecological and economical benefit society technology',
#  'the whole scene with jared the driverless car had dying such perfect role for him comin from the office',
#  'test driving google driverless car look mom hands google robotic cars have about equipment',
#  'pointed this blog series the impact google driverless car fascinating',
#  'the best thing read along time driverless cars and mobility',
#  'the advent driverless cars presents compelling bigdata predictive software opportunity',
#  'focusing mass transit grand but driverless cars will play tremendous supporting role mass adoption',
#  'disruptions how driverless cars could reshape cities seen some those cars the crazy',
#  'major road blocks linger but driverless cars are here stay cool hate driving smallbiz innovation',
#  'driverless car invented google has completed over miles and only had two accidents when humans other cars hit',
#  'for one cannot wait for driverless cars because you all drive fer shit',
#  'with amount wrecks should the first have driverless car haha',
# ...
#  'can wait until driverless cars actually makes this true',
#  'this will blow your mind have been wanting say that how driverless cars remake our transit system',
#  'driverless cars are legal thats probably the most intelligent thing ever',
#  'there has been safe nearly driverless transportation for centuries belt railway',
#  'california legalizes driverless cars wtf right when leave california too',
#  'you trust driverless cars long they use google maps',
#  'wsj auto critic dan neil why driverless cars are inevitable and why that good thing can text',
#  'wired score california becomes second state after nevada legalize driverless cars can drink not drive',
#  'happy birthday google too young drive problem make driverless cars',
#  'nerds galore becomes state after legalize driverless cars robot automotive kitt knightrider',
#  'can wait get those driverless cars can you imagine can like otter said animal house road trip',
#  'driverless save operating costs and increase frequency',
#  'driverless cars see great future just imagine what you could during your commute binge watch the latest netflix series ces',
#  'about get hands off with the driverless las vegas this going experience ces cartech audi',
#  'just really want said driverless car for this eight hour drive',
#  'bmw hits the performance limits with its driverless car via',
#  'crazy possible see the day when our drunkasses are being driven around driverless taxis',
#  'very cool the streets ann arbor will soon filled with driverless cars',
#  'don know about other states but the average minnesotan terrible driver can wait for driver less cars',
#  'driverless cars now all about that less people behind the wheel texting and not paying attention the road ces',
#  'txtransforum the future electric roads and driverless vehicles ready now',
#  'driverless cars are needed the las vegas strip there pedestrian fatality almost every week',
#  'well google poised release their driverless car that might the way',
#  'legal states driverless car has gone miles accident says',
#  'driverless public transit like buses now you have attention but that long way off won see that for while',
#  'can worse than the brainless ones the road now georgia could first have driverless cars',
#  'hurry with that driverless car already eating tweeting and driving the same time not easy',
#  'not only cool but they have the potential revolutionize eliminate traffic you ride driverless car would',
#  'driverless cars can come soon enough',
#  'dear really excited about these driverless firetrucks can ride one',
#  'big news thismorning gmcares week drives off today future plans for driverless thefutureisnow',
#  'driverless cars talking atms products designed with can good for everyone voteto topoli',
#  'gotta love guy pitching driverless cars solution climate change innovators rule the future',
#  'apple gonna put credit card phone google been there done that busy curing death and building driverless cars',
#  'people freaking out about auto pilot driverless cars because humans behind the wheel totally safe',
#  'heard that driverless cars were coming and didn want miss his shot cruising down the',
#  'mary barra new super cruise cars will safer ready for driverless cars yes',
#  'love reading about driverless cars smart vehicles has entire section different takes here',
#  'can wait for cars drive themselves networked car mandated future vehicles autonomousdriving via',
#  'you ever had any doubt live the future car just parallel parked itself insanely cool technology',
#  'the future love own self driving car but afraid get insanely car sick every time got inside',
#  'all really want self driving car future tech predictions via lis',
#  'the future here saw google self driving car the today',
#  'took ride google self driving car the future here people',
#  'sergey brin announces fully self driving car codecon steering wheel brakes nothing future',
#  'the future here google self driving car project',
#  'google self driving car isn car the future',
#  'spotted google car driving itself the future jabee ewbanhtour google campus',
#  'self driving car the future here highway',
#  'yesterday was ride with google self driving car today model thanks you can buy the future today',
#  'saw google self driving car today freaky the future now google tech',
#  'crossed the street front google self driving car lived tweet about the future',
#  'saw google self driving car the way home the future closer than you think',
#  'saw google self driving car leaving mcdonalds today the future',
#  'with google self driving car and spacex first manned spacecraft think safe say the future here',
#  'generally feel like are already living the future but also want self driving car',
#  'need drink now fortunately home have gin want self driving google car radar laser pedestrian detection',
#  'google car thanks for picture google maps street view right here jerome avenue brooklyn new york united states',
#  'nissan has promised that will have multiple affordable self driving car models and google does',
#  'this cannot happen soon enough google designing its own self driving car',
#  'how long til google self driving car takes bar hoping',
#  'just saw the google car omgeee',
#  'chilling the google car google streets canadian tire',
#  'between truvada naloxone and google cars could substantially reduce aids drug overdoses and car crashes dragging our feet costs lives',
#  'saw google car driving itself cool way better then the google street view cars',
#  'saw the google car pretty dope',
#  'look closely you will see the reflection google car screen shot from google maps',
#  'saw google car today and mom was excited chased down lol',
#  'saw google car tiburon',
#  'was just passed google self driving car',
#  'google car would nice for days like this',
#  'thank google for the self driving car',
#  'just read your article the google car very insightful looking fwd part',
#  'google self driving car neat starbucks',
#  'just saw google self driving car drive pretty sweet',
#  'today was tailgated tesla model and passed google car that was driving itself valley driving cooler than driving',
#  'had self driving car would drunk all day every day google drinking driving',
#  'yay google self driving car',
#  'saw google self driving car yesterday was not driving slowly the fast lane that major improvement over humans already',
#  'the google self driving car san mateo',
#  'wish had google self driving car right now sftraffic',
#  'hate this drive more every time make want self driving car',
#  'steva mahan does some the best driving his life google self driving car yeah and hes blind',
#  'google self driving car perfect for pistol duels',
#  'beautiful day drive next google self driving car google donttakepictureswhiledriving yolo',
#  'drove past tesla garage right the same time google self driving car thats for',
#  'google self driving car also headed towards wdayrising futureisnow',
#  'omg just saw the google car lol',
#  'first governor allow testing google self driving car public streets thanks for moving technology forward impact',
#  'saw the google car locksburg the other day thought was cool',
#  'sign for the google car',
#  'was driving next the google car badass',
#  'behind self driving car highway kinda enchanted the whirring device mounted the roof',
#  'the google car',
#  'google self driving car the background',
#  'jammin spice girls with the google car sprangbrake',
#  'just saw first google car',
#  'just saw the google car sepulveda blvd pretty cool',
#  'days like this self driving from would very helpful selfdriving google car',
#  'life complete google car found google googlecar',
#  'just saw the google car',
#  'saw the google car and want follow isthatweird',
#  'google self driving car drove itself starbucks lol starbucks',
#  'ppistone was top day the life amanda and saw the google car',
#  'the google self driving car which still drives better than most drivers not sure what top',
#  'the google car kensington yyc',
#  'google fine tunes its self driving car for city streets dream getting closer reality',
#  'totally behind the google car',
#  'google releases stunning new video their self driving car urban traffic situations great',
#  'ready for this mainstream google self driving car city streets',
#  'self driving car city streets google propaganda but impressive',
#  'man think ready for google car can get work done while driving might little risky the pali though',
#  'can wait til high school reunion ima talk about how seen google car today and there was someone actually driving drone shit',
#  'just got confirmed for google self driving car test ride thank you google team',
#  'that awesome moment when you walking work and the google car passes you will forever the internet',
#  'just passed the google car cool google',
#  'just seen google car driving around person for the first time that was pretty neat',
#  'passed the google car again holla',
#  'google has self driving car can have one',
#  'google self driving car hway this morning zey ahr amonk',
#  'the google car just passed',
#  'omg google car',
#  'just saw the google car daymade',
#  'just saw the google car the way home from school',
#  'vml how fast cars left the google car would reach nyc before the broadband ches independence',
#  'feel like part life complete just passed the google car',
#  'currently driving behind the google car see later iowa too famous now',
#  'just saw the car very cool',
#  'just saw google self driving car front the road while was stuck yaris',
#  'google self driving car neighborhood',
#  'can wait for the google car standard for all cars that may sleep the way into work the car drives itself',
#  'self driving car publicityfinally yay google much awaited video',
#  'google car nice incremental step for self driving cars acceptance regulators critical not styling speed short term mph',
#  'drive just unveiled self driving car prototype steering wheel pedals',
#  'awesome the next stop the road self driving car',
#  'can someone build google car regex and make little busy but want',
#  'switch from uberx google self driving car tomorrow their investment the latter makes sense',
#  'google has self driving car with steering wheel nigga made',
#  'not good driver this excites google unveils market ready self driving car',
#  'wish google tesla and kia would mate and have self driving electric cheap car nine months',
#  'day will acquire google car and gonna put dog the drivers seat and ppl will literally think dog driving car',
#  'the google car thing interesting because its pissing off car people and transit people think has place',
#  'don think there person more need the google self driving car than myself',
#  'any one wants buy the google car happily accept',
#  'checkin out the self driving car our tour google the fellows pretty cool',
#  'tired and wish google car drive home that can take nap route',
#  'google shopping express would lot cooler was delivered the google self driving car',
#  'google car granbury the map',
#  'google car spotted just crossed the market bridge ilovecha',
#  'just saw google car dreams come true',
#  'impressive test drive the self driving car',
#  'just drove google car now forever famous',
#  'google self driving car prototype cute not all few thousand pounds deadly hurtling robotic glass and steel want one',
#  'how cute this prototype google self driving car wat widdle cutie certainly not terrifying killer robot',
#  'this can save tons time the google car takes step away from boring',
#  'this some next level stuff the next stop the road self driving car',
#  'wow the google car takes step away from boring',
#  'extremely exciting and hideous the next stop the road self driving car',
#  'what the heck just saw self driving google car pretty pretty cool you won need drivers license these are sucessful',
#  'just saw google self driving car hands',
#  'google car probably safer',
#  'weird excited see the google car the road paul ann baptist church',
#  'google self driving car has driven miles without accident cali when hits mil they need release that shit',
#  'well life complete finally seen the mythical google car lol',
#  'but you live till your google car will able drive you home more dui smiling',
#  'check out google improvements their self driving car lexus google technology thefuture',
#  'the google car courtesy dream',
#  'the google self driving car cool but obvious next step now that almost looks archaic',
#  'the google self driving car cool but obvious next step now that almost looks archaic',
#  'want the road not own google unveils self driving car with steering wheel',
#  'wow microsoft announces babelfish and google announces the jetson self driving car what apple got kraken',
#  'announcing two passenger self driving car steering wheel exciting how close this technology codecon',
#  'the new car looks like plastic koala with fez like',
#  'wrong want self driving car that looks like codecon',
#  'the google car limited mph federal requirements interesting',
#  'google car may mean cheaper car insurance goog',
#  'next car purchase will google self driving car check out the interwebs google selfdrivingcar',
#  'google showed new from scratch self driving car pretty amazing emmascar',
#  'google car',
#  'can wait for the development tools for the new google car',
#  'cool google unveils their new self driving car naming google storage after their storage app google drive googleselfdrivingcar',
#  'genuinely torn about the google car design its early prototype after watching the vid initial disgust became mild admiration',
#  'just saw the google self driving car near hayward yay technology',
#  'highlight day seeing the google car',
#  'the google campus today self driving car with radar that images out view around played chicken and won',
#  'the bay area you occasionally run into fun things like this the google self driving car',
#  'have you seen the google self driving car would perfect for eating and driving lol',
#  'encounter with self driving car like test limits evasiveaction',
#  'hey google want self driving car',
#  'thanks for coming aucrisiscomms was great hear about and crisis but bring the self driving car next time',
#  'today rode self driving car was fun whereto',
#  'google car the google car maps triborough bridge',
#  'google car will thanks computers',
#  'cant wait stand naked the front porch goes ont hear the google car was ont today',
#  'just got word that the self driving google car around philadelphia right now the look out',
#  'android auto gets real google car',
#  'googlefacts suggestion the google self driving car should have feeling lucky button that drives you random location',
#  'last sat was out self driving car this week have drive myself feel normal bayareacomplaints stworldproblems',
#  'bro you not thinking get the self driving google car then you can eat food and roam',
#  'definitely ready for google car now',
#  'cool things you see living mountainview the google self driving car google',
#  'get rich buying google self driving car for the drunken debauchery nights',
#  'finally saw google car been dying see one robert carr chapel',
#  'always wanted see google car arresteddevelopment robert carr chapel',
#  'google made self driving car and miles only got into accident and was the other drivers fault soon very soon',
#  'stand still traffic much fun need car that drives can get some work done',
#  'google car',
#  'the way home yesterday saw handful teslas google self driving car and solar powered car love silicon valley',
#  'thought the day google car combined with tesla would transform the car industry',
#  'vroom car internetradio rainsummits saftey will resolved car google self driving cars',
#  'google self driving car sighting carwoo',
#  'degrees driving tesla passing google self driving car love silicon valley',
#  'just saw google car past road cool',
#  'saw google car today',
#  'just want home you know wish had google car for those drunk high tired nights smart lazy lol drivemehome',
#  'google self driving car thanks mayep',
#  'saw the google car way school again that twice month that good luck right need for this final',
#  ...]

# %%
df['cleaned_tweet'] = np.array([ tweet_cleaner(tweet) for tweet in df.tweet ])
titles = df['cleaned_tweet'].fillna('')

from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features = 300, 
                             ngram_range=(1, 1), 
                             stop_words='english',
                             binary=True)

# Use `fit` to learn the vocabulary of the titles
vectorizer.fit(titles)

# Use `tranform` to generate the sample X word matrix - one column per feature (word or n-grams)
X = vectorizer.transform(titles)

# %%
def trained_model(model,X,y):
    
    #scoring results
    scoresR = cross_val_score(model, X, y, cv=30, scoring='recall')
    print('CV Recall {}, Average Recall {}'.format(scoresR, scoresR.mean()))
    # F1 = (2 x recall x precision) / (recall + precision)
    scoresf1 = cross_val_score(model, X, y, cv=30, scoring='f1')
    print('CV F1 {}, Average F1 {}'.format(scoresf1, scoresf1.mean()))
    scoresAUC = cross_val_score(model, X, y, cv=30, scoring='roc_auc')
    print('CV AUC {}, Average AUC {}'.format(scoresAUC, scoresAUC.mean()))
    
    #output trained model
    trained_model = model.fit(X, y)
    
    return trained_model

# %%
# select model: logistic regression
from sklearn.linear_model import LogisticRegression
modellr = LogisticRegression(class_weight= 'balanced') 

#define model, X and y
model = modellr
X = CVectorizer(df)
y = df.neg_senti
df.head()
# Out:
#    sentiment                                              tweet  neg_senti  \
# 0          5  Two places I'd invest all my money if I could:...          0
# 1          5  Awesome! Google driverless cars will help the ...          0
# 2          5  Autonomous vehicles could reduce traffic fatal...          0
# 3          5  Really good presentation from Jan Becker on Bo...          0
# 4          5  Ford just revealed it's Automated Ford Fusion ...          0
#
#                                        cleaned_tweet
# 0  two places invest all money could printing and...
# 1  awesome google driverless cars will help the b...
# 2  autonomous vehicles could reduce traffic fatal...
# 3  really good presentation from jan becker bosch...
# 4  ford just revealed automated ford fusion hybri...

# %%
Output_model = trained_model(model,X,y)

#feature importance
all_feature_names = vectorizer.get_feature_names()
feature_importances = pd.DataFrame({'lrFeatures' : all_feature_names, 'Importance Score': Output_model.coef_[0].tolist()})
feature_importances.sort_values('Importance Score', ascending=False).head(5)
# Out:
# CV Recall [0.73076923 0.76923077 0.73076923 0.65384615 0.65384615 0.76923077
#  0.80769231 0.61538462 0.26923077 0.46153846 0.5        0.57692308
#  0.53846154 0.69230769 0.73076923 0.65384615 0.57692308 0.80769231
#  0.76923077 0.65384615 0.65384615 0.69230769 0.80769231 0.61538462
#  0.65384615 0.72       0.88       0.72       0.68       0.76      ], Average Recall 0.6714871794871794
# CV F1 [0.67857143 0.63492063 0.7037037  0.68       0.59649123 0.74074074
#  0.7        0.47058824 0.26415094 0.375      0.35616438 0.42253521
#  0.3943662  0.52941176 0.61290323 0.51515152 0.47619048 0.71186441
#  0.55555556 0.53125    0.52307692 0.61016949 0.6        0.52459016
#  0.55737705 0.58064516 0.61971831 0.57142857 0.53125    0.52777778], Average F1 0.5531864366323949
# CV AUC [0.85225885 0.80616606 0.87851038 0.88766789 0.83150183 0.90781441
#  0.87728938 0.6978022  0.54945055 0.53113553 0.51587302 0.54578755
#  0.55128205 0.76678877 0.7954823  0.72283272 0.65689866 0.84371184
#  0.78113553 0.72893773 0.74297924 0.72710623 0.73809524 0.72832723
#  0.73595849 0.75365079 0.83936508 0.77873016 0.65968254 0.76129032], Average AUC 0.7397837514934289
#      lrFeatures  Importance Score
# 128        jobs          2.351344
# 53        doesn          1.993579
# 97   government          1.851629
# 132         law          1.563260
# 55         dont          1.532249

# %%
#predict on incoming tweets
test_tweet = vectorizer.transform(df_test.tweet)
df_test['Predicted_Senti'] = Output_model.predict(test_tweet).tolist()
df_test
# Out:
#                                                tweet  Predicted_Senti
# 0  Two places Id invest all my money if I could: ...                1
# 1  Awesome! Google driverless cars will help the ...                0

# %%
def updatetweets(df_test):
    
    conn = create_db_connection()
    cur = conn.cursor()

    for i in range(len(df_test)):
        sql_insert = '''insert into existing_tweets (tweet, sentiment)
        values ('{0}', '{1}') 
        '''.format(df_test.tweet[i].replace("'",""), df_test.Predicted_Senti[i])
        cur.execute(sql_insert)
        conn.commit()

    conn.close()
    
    print('New tweet sentiment pairs added to existing_tweets table')

updatetweets(df_test)
# Out:
# New tweet sentiment pairs added to existing_tweets table

# %%
def deletetweets(table_name):  
    
    conn = create_db_connection()
    cur = conn.cursor()
    cur.execute(
        sql.SQL("DELETE FROM {}")
            .format(sql.Identifier(table_name)))
    conn.commit()
    conn.close()
    
    print('All records were deleted from table: %s'%(table_name))

deletetweets('incoming_tweets')
deletetweets('existing_tweets')
# Out:
# All records were deleted from table: incoming_tweets
# All records were deleted from table: existing_tweets

# %%
#simulate demo

def demo():
    #generate random tweets
    gettweets()
    #set dummy condition
    condition = 1
    
    while condition != 0:
        
        #convert osa incoming tweets table to pandas df
        df_test = topddf()
        
        #add predicted sentiment column
        test_tweet = vectorizer.transform(df_test.tweet)
        df_test['Predicted_Senti'] = Output_model.predict(test_tweet).tolist()
        print(df_test.head())
        
        #update new records into osa existing tweets table
        updatetweets(df_test)
        
        #set condition to stop while loop
        deletetweets('incoming_tweets')
        
        conn = create_db_connection()
        cur = conn.cursor()
        cur.execute("""SELECT * from incoming_tweets limit 1""")
        condition = cur.fetchone() 
        conn.close()

        if condition is None:
            condition = 0

# %%
# test demo
demo()
# Out:
# Dummy Incoming tweet table created
#                                                tweet  Predicted_Senti
# 0  Two places Id invest all my money if I could: ...                1
# 1  Awesome! Google driverless cars will help the ...                0
# New tweet sentiment pairs added to existing_tweets table
# All records were deleted from table: incoming_tweets

# %%
import psycopg2
from pprint import pprint

# %%
class DatabaseConnection:
    def __init__(self):
        try:
            self.connection = psycopg2.connect(
                "dbname='osa' user='janaka' host='osa.c97j4f5sor7n.eu-west-1.rds.amazonaws.com' password='1qazZXC!23' port='5432'")
            self.connection.autocommit = True
            self.cursor = self.connection.cursor()
        except:
            pprint("Cannot connect to datase")

    def create_table(self):
        create_table_command = "CREATE TABLE pet(id serial PRIMARY KEY, name varchar(100), age integer NOT NULL)"
        self.cursor.execute(create_table_command)

    def insert_new_record(self):
        new_record = ("misa meo6", "6")
        insert_command = "INSERT INTO pet(name, age) VALUES('" + new_record[0] + "','" + new_record[1] + "')"
        pprint(insert_command)
        self.cursor.execute(insert_command)
        
    def query_all(self):
        self.cursor.execute("SELECT * FROM pet")
        cats = self.cursor.fetchall()
        for cat in cats:
            pprint("each pet : {0}".format(cat))

    def update_record(self):
        update_command = "UPDATE pet SET age=10 WHERE id=1"
        self.cursor.execute(update_command)

    def drop_table(self):
        drop_table_command = "DROP TABLE pet"
        self.cursor.execute(drop_table_command)

# %%
if __name__== '__main__':
    database_connection = DatabaseConnection()
    #database_connection.create_table()
    #database_connection.insert_new_record()
    #database_connection.query_all()
    #database_connection.update_record()
    database_connection.drop_table()
